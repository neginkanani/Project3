# %%
# !pip install splinter
# !pip install selenium
# !pip install webdriver-manager

# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import requests
import pprint
from itertools import chain
import pymongo

# %%
def get_brewery_api():
    '''Reading from the brewery database API'''
    i = 0
    url = f'https://api.openbrewerydb.org/breweries?page={i}&per_page=200'
    brewery_list = []
    for i in range(1,44):
        response = requests.get(url)
        brewery_data = response.json()
        brewery_list.append(brewery_data)
        time.sleep(1)
    all_brewerys_pd = list(chain.from_iterable(brewery_list))
    return all_brewerys_pd

# %%
data_api=get_brewery_api()

# %%
collection_api = db.brewery_api
collection_api.insert_many(data_api)

# %%
def scrape_untapped():
    '''Scrape the untapped website to collect the latest beer information
    open the website'''
    executable_path = {'executable_path': ChromeDriverManager().install()}
    browser = Browser('chrome', **executable_path, headless=False)
    #reading the html code
    html = browser.html
    soup = BeautifulSoup(html, "lxml")
    
    url_untapped = 'https://untappd.com/brewery/top_rated?country=ireland'
    browser.visit(url_untapped)
    time.sleep(1)
    breweries = browser.find_by_xpath('//*[@id="slide"]/div[3]/div/div[1]/div/div[4]')
    
    all_brewery_info = []
    for brewery in breweries:
        title_link = brewery.text
        all_brewery_info.append(title_link)
        time.sleep(2)


    brewery_list = all_brewery_info[0].split("\n")
    
    
    for item in all_brewery_info:
        if item == "Report":
            all_brewery_info.remove("Report Ad")
    
    brewery_list_all = []
    i = 0
    while i < len(brewery_list):
        if i == "Report Ad":
            brewery_list.remove("Report Ad")
        else:
         try:
            brewery = brewery_list[i:i+5]
            #print(brewery)
            dictionary = dict()
            dictionary['brewery_name'] = brewery[0]
            dictionary['brewery_location'] = brewery[1]
            dictionary['brewery_type'] = brewery[2]
            dictionary['number_beers'] = brewery[3]
            dictionary['brewery_ratings'] = brewery[4]
         except IndexError:
            print(f"This batch broke: {brewery}")
            break
        brewery_list_all.append(dictionary)
        i += 5
    browser.quit()
    return brewery_list_all

# %%
untappd=scrape_untapped()

# %%
untappd
# Out:
# [{'brewery_name': 'Land & Labour',
#   'brewery_location': 'Galway, County Galway Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '9 Beers 4,624 Ratings',
#   'brewery_ratings': '(4.01)'},
#  {'brewery_name': 'Two Sides Brewing Co.',
#   'brewery_location': 'Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '12 Beers 2,316 Ratings',
#   'brewery_ratings': '(3.953)'},
#  {'brewery_name': 'Otterbank Brewing & Blending',
#   'brewery_location': 'Muff, County Donegal Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '53 Beers 2,839 Ratings',
#   'brewery_ratings': '(3.825)'},
#  {'brewery_name': 'Whiplash',
#   'brewery_location': 'Dublin, County Dublin Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '103 Beers 231,742 Ratings',
#   'brewery_ratings': '(3.819)'},
#  {'brewery_name': 'LINEMAN',
#   'brewery_location': 'Rathcoole, County Dublin Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '21 Beers 7,291 Ratings',
#   'brewery_ratings': '(3.796)'},
#  {'brewery_name': 'Third Barrel Brewing',
#   'brewery_location': 'Dublin, County Dublin Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '78 Beers 17,377 Ratings',
#   'brewery_ratings': '(3.788)'},
#  {'brewery_name': "Larkin's Brewing Co",
#   'brewery_location': 'Kilcoole, County Wicklow Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '76 Beers 28,903 Ratings',
#   'brewery_ratings': '(3.775)'},
#  {'brewery_name': 'Dead Centre Brewing',
#   'brewery_location': 'Athlone, County Westmeath Ireland',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '76 Beers 5,699 Ratings',
#   'brewery_ratings': '(3.774)'},
#  {'brewery_name': 'Crafty Bear Brewing',
#   'brewery_location': 'Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '14 Beers 1,155 Ratings',
#   'brewery_ratings': '(3.772)'},
#  {'brewery_name': 'Soulwater',
#   'brewery_location': 'Headford Road, Co. Galway Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '17 Beers 2,181 Ratings',
#   'brewery_ratings': '(3.747)'},
#  {'brewery_name': 'Lough Gill Brewery',
#   'brewery_location': 'Sligo, County Sligo Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '90 Beers 39,265 Ratings',
#   'brewery_ratings': '(3.746)'},
#  {'brewery_name': 'Beoir Chorca Dhuibhne (West Kerry Brewery)',
#   'brewery_location': 'Ballyferriter, County Kerry Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '23 Beers 6,740 Ratings',
#   'brewery_ratings': '(3.742)'},
#  {'brewery_name': 'DOT Brew',
#   'brewery_location': 'Dublin, County Dublin Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '362 Beers 49,539 Ratings',
#   'brewery_ratings': '(3.735)'},
#  {'brewery_name': 'Wide Street Brewing',
#   'brewery_location': 'Ballymahon, County Longford Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '39 Beers 2,858 Ratings',
#   'brewery_ratings': '(3.734)'},
#  {'brewery_name': 'O Brother Brewing',
#   'brewery_location': 'Kilcoole, County Wicklow Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '102 Beers 58,991 Ratings',
#   'brewery_ratings': '(3.724)'},
#  {'brewery_name': 'Western Herd',
#   'brewery_location': 'Kilmaley, County Clare Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '41 Beers 5,962 Ratings',
#   'brewery_ratings': '(3.708)'},
#  {'brewery_name': 'Burren Brewery',
#   'brewery_location': 'Lisdoonvarna, Munster Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '8 Beers 1,434 Ratings',
#   'brewery_ratings': '(3.688)'},
#  {'brewery_name': 'Nohoval Drinks Company Ltd',
#   'brewery_location': 'Nohoval, County Cork Ireland',
#   'brewery_type': 'Cidery',
#   'number_beers': '17 Beers 6,459 Ratings',
#   'brewery_ratings': '(3.687)'},
#  {'brewery_name': 'Galway Bay Brewery',
#   'brewery_location': 'Oranmore, County Galway Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '142 Beers 188,984 Ratings',
#   'brewery_ratings': '(3.679)'},
#  {'brewery_name': 'Mescan Brewery',
#   'brewery_location': 'Westport, County Mayo Ireland',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '20 Beers 5,837 Ratings',
#   'brewery_ratings': '(3.665)'},
#  {'brewery_name': 'Kinnegar Brewing',
#   'brewery_location': 'Letterkenny, County Donegal Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '83 Beers 92,539 Ratings',
#   'brewery_ratings': '(3.661)'},
#  {'brewery_name': "Sullivan's Brewing Company",
#   'brewery_location': 'Kilkenny, County Kilkenny Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '13 Beers 26,626 Ratings',
#   'brewery_ratings': '(3.651)'},
#  {'brewery_name': 'Killarney Brewing Company',
#   'brewery_location': 'Killarney, County Kerry Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '39 Beers 23,076 Ratings',
#   'brewery_ratings': '(3.647)'},
#  {'brewery_name': 'Hopfully Brewing',
#   'brewery_location': 'Waterford, Munster Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '49 Beers 13,448 Ratings',
#   'brewery_ratings': '(3.646)'},
#  {'brewery_name': 'Hope Beer',
#   'brewery_location': 'Kilbarrack, County Dublin Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '47 Beers 25,798 Ratings',
#   'brewery_ratings': '(3.635)'},
#  {'brewery_name': 'Elbow Lane Craft Beer',
#   'brewery_location': 'Cork, County Cork Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '16 Beers 3,220 Ratings',
#   'brewery_ratings': '(3.633)'},
#  {'brewery_name': 'BrewDog Outpost Dublin',
#   'brewery_location': 'Dublin, County Dublin Ireland',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '55 Beers 1,715 Ratings',
#   'brewery_ratings': '(3.628)'},
#  {'brewery_name': 'Wicklow Wolf Brewing Company',
#   'brewery_location': 'Newtown Mount Kennedy, County Wicklow Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '112 Beers 64,492 Ratings',
#   'brewery_ratings': '(3.626)'},
#  {'brewery_name': 'WhiteField Brewery',
#   'brewery_location': 'Templemore, Munster Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '75 Beers 8,949 Ratings',
#   'brewery_ratings': '(3.624)'},
#  {'brewery_name': 'YellowBelly Beer (Ireland)',
#   'brewery_location': 'Pembrokestown, Leinster Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '163 Beers 48,039 Ratings',
#   'brewery_ratings': '(3.623)'},
#  {'brewery_name': 'Curious Society',
#   'brewery_location': 'Kilcoole, County Wicklow Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '9 Beers 5,004 Ratings',
#   'brewery_ratings': '(3.623)'},
#  {'brewery_name': "Dick Mack's Brewhouse",
#   'brewery_location': 'Dingle, County Kerry Ireland',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '18 Beers 6,037 Ratings',
#   'brewery_ratings': '(3.622)'},
#  {'brewery_name': 'Rising Sons Brewery',
#   'brewery_location': 'Cork, County Cork Ireland',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '73 Beers 14,001 Ratings',
#   'brewery_ratings': '(3.613)'},
#  {'brewery_name': 'Trouble Brewing',
#   'brewery_location': 'Kill, County Kildare Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '86 Beers 40,460 Ratings',
#   'brewery_ratings': '(3.606)'},
#  {'brewery_name': 'Wicklow Brewery',
#   'brewery_location': 'Redcross, County Wicklow Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '56 Beers 6,117 Ratings',
#   'brewery_ratings': '(3.594)'},
#  {'brewery_name': 'Brewtonic',
#   'brewery_location': 'Dublin, Leinster Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '25 Beers 1,927 Ratings',
#   'brewery_ratings': '(3.589)'},
#  {'brewery_name': 'Treaty City Brewery',
#   'brewery_location': 'Limerick, County Limerick Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '82 Beers 6,946 Ratings',
#   'brewery_ratings': '(3.585)'},
#  {'brewery_name': 'Eight Degrees Brewing',
#   'brewery_location': 'Mitchelstown, County Cork Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '81 Beers 76,154 Ratings',
#   'brewery_ratings': '(3.58)'},
#  {'brewery_name': 'Black Donkey Brewing',
#   'brewery_location': 'Ballinlough, Co. Roscommon Ireland',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '26 Beers 6,028 Ratings',
#   'brewery_ratings': '(3.576)'},
#  {'brewery_name': 'Stone Barrel Brewing',
#   'brewery_location': 'Dublin, County Dublin Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '30 Beers 13,878 Ratings',
#   'brewery_ratings': '(3.574)'},
#  {'brewery_name': 'The White Hag Irish Brewing Company',
#   'brewery_location': 'Ballymote, County Sligo Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '111 Beers 244,902 Ratings',
#   'brewery_ratings': '(3.573)'},
#  {'brewery_name': 'BRÚ Brewery',
#   'brewery_location': 'Trim, Leinster Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '30 Beers 10,167 Ratings',
#   'brewery_ratings': '(3.571)'},
#  {'brewery_name': 'Ballykilcavan',
#   'brewery_location': 'Stradbally, County Laois Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '39 Beers 4,939 Ratings',
#   'brewery_ratings': '(3.571)'},
#  {'brewery_name': '12 Acres Brewing Company',
#   'brewery_location': 'Portarlington, County Laois Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '14 Beers 7,412 Ratings',
#   'brewery_ratings': '(3.57)'},
#  {'brewery_name': 'Kildare Brewing Co.',
#   'brewery_location': 'Sallins, County Kildare Ireland',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '32 Beers 1,008 Ratings',
#   'brewery_ratings': '(3.569)'},
#  {'brewery_name': "Dan Kelly's Cider",
#   'brewery_location': 'Drogheda, County Louth Ireland',
#   'brewery_type': 'Cidery',
#   'number_beers': '11 Beers 1,008 Ratings',
#   'brewery_ratings': '(3.567)'},
#  {'brewery_name': 'Rascals Brewing Co',
#   'brewery_location': 'Dublin, Leinster Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '140 Beers 57,468 Ratings',
#   'brewery_ratings': '(3.563)'},
#  {'brewery_name': 'Blacks Brewery',
#   'brewery_location': 'Kinsale, County Cork Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '41 Beers 44,723 Ratings',
#   'brewery_ratings': '(3.554)'},
#  {'brewery_name': 'HOPKINS & HOPKINS',
#   'brewery_location': 'Dublin, County Dublin Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '21 Beers 2,131 Ratings',
#   'brewery_ratings': '(3.551)'},
#  {'brewery_name': 'Spiddal River',
#   'brewery_location': 'Spiddal, Co. Galway Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '8 Beers 1,690 Ratings',
#   'brewery_ratings': '(3.536)'}]

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
#client.drop_database('brewery_db')
# Define database and collection

db = client.brewery_db
collection_untappd = db.brewery_untappd
collection_untappd.insert_many(untappd)
