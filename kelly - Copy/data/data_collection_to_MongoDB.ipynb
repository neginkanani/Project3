# %%
# !pip install splinter
# !pip install selenium
# !pip install webdriver-manager

# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import requests
import pprint
from itertools import chain
import pymongo

# %%
def get_brewery_api():
    '''Reading from the brewery database API'''
    i = 0
    url = f'https://api.openbrewerydb.org/breweries?page={i}&per_page=200'
    brewery_list = []
    for i in range(1,44):
        response = requests.get(url)
        brewery_data = response.json()
        brewery_list.append(brewery_data)
        time.sleep(1)
    all_brewerys_pd = list(chain.from_iterable(brewery_list))
    return all_brewerys_pd

# %%
data_api=get_brewery_api()

# %%
collection_api = db.brewery_api
collection_api.insert_many(data_api)

# %%
def scrape_untapped():
    '''Scrape the untapped website to collect the latest beer information
    open the website'''
    executable_path = {'executable_path': ChromeDriverManager().install()}
    browser = Browser('chrome', **executable_path, headless=False)
    #reading the html code
    html = browser.html
    soup = BeautifulSoup(html, "lxml")
    
    url_untapped = 'https://untappd.com/brewery/top_rated?country=italy'
    browser.visit(url_untapped)
    time.sleep(1)
    breweries = browser.find_by_xpath('//*[@id="slide"]/div[3]/div/div[1]/div/div[4]')
    
    all_brewery_info = []
    for brewery in breweries:
        title_link = brewery.text
        all_brewery_info.append(title_link)
        time.sleep(2)


    brewery_list = all_brewery_info[0].split("\n")
    
    
    for item in all_brewery_info:
        if item == "Report":
            all_brewery_info.remove("Report Ad")
    
    brewery_list_all = []
    i = 0
    while i < len(brewery_list):
        if i == "Report Ad":
            brewery_list.remove("Report Ad")
        else:
         try:
            brewery = brewery_list[i:i+5]
            #print(brewery)
            dictionary = dict()
            dictionary['brewery_name'] = brewery[0]
            dictionary['brewery_location'] = brewery[1]
            dictionary['brewery_type'] = brewery[2]
            dictionary['number_beers'] = brewery[3]
            dictionary['brewery_ratings'] = brewery[4]
         except IndexError:
            print(f"This batch broke: {brewery}")
            break
        brewery_list_all.append(dictionary)
        i += 5
    browser.quit()
    return brewery_list_all

# %%
untappd=scrape_untapped()

# %%
untappd
# Out:
# [{'brewery_name': 'Brasseria Della Fonte',
#   'brewery_location': 'Pienza, Toscana Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '82 Beers 15,020 Ratings',
#   'brewery_ratings': '(4.057)'},
#  {'brewery_name': "Ca' del Brado",
#   'brewery_location': 'Pianoro, Emilia-Romagna Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '37 Beers 36,886 Ratings',
#   'brewery_ratings': '(3.987)'},
#  {'brewery_name': 'Cantina Errante',
#   'brewery_location': "Barberino Val d'Elsa, Toscana Italy",
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '45 Beers 5,227 Ratings',
#   'brewery_ratings': '(3.981)'},
#  {'brewery_name': 'Alder Beer Co.',
#   'brewery_location': 'Seregno, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '55 Beers 21,937 Ratings',
#   'brewery_ratings': '(3.979)'},
#  {'brewery_name': 'Siemàn',
#   'brewery_location': 'Villaga, Veneto Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '20 Beers 6,172 Ratings',
#   'brewery_ratings': '(3.921)'},
#  {'brewery_name': 'Ritual Lab',
#   'brewery_location': 'Formello, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '88 Beers 41,572 Ratings',
#   'brewery_ratings': '(3.902)'},
#  {'brewery_name': 'CRAK Brewery',
#   'brewery_location': 'Campodarsego, Veneto Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '258 Beers 179,082 Ratings',
#   'brewery_ratings': '(3.867)'},
#  {'brewery_name': 'Maestri del Sannio',
#   'brewery_location': 'Cerreto Sannita, Campania Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '53 Beers 1,957 Ratings',
#   'brewery_ratings': '(3.859)'},
#  {'brewery_name': 'Klanbarrique',
#   'brewery_location': 'Rovereto, Trentino-Alto Adige/Südtirol Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '40 Beers 11,958 Ratings',
#   'brewery_ratings': '(3.853)'},
#  {'brewery_name': 'Birrificio MalaRipe',
#   'brewery_location': 'Ripe San Ginesio, Marche Italy',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '29 Beers 1,087 Ratings',
#   'brewery_ratings': '(3.834)'},
#  {'brewery_name': 'Birrificio Stradaregina',
#   'brewery_location': 'Vigevano, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '99 Beers 7,233 Ratings',
#   'brewery_ratings': '(3.827)'},
#  {'brewery_name': 'Birrificio Montegioco',
#   'brewery_location': 'Montegioco, Piemonte Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '65 Beers 20,078 Ratings',
#   'brewery_ratings': '(3.826)'},
#  {'brewery_name': 'Mukkeller',
#   'brewery_location': "Porto Sant'Elpidio, Marche Italy",
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '86 Beers 10,929 Ratings',
#   'brewery_ratings': '(3.823)'},
#  {'brewery_name': 'Vento Forte',
#   'brewery_location': 'Bracciano, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '195 Beers 14,822 Ratings',
#   'brewery_ratings': '(3.822)'},
#  {'brewery_name': 'Bonavena Brewing Company',
#   'brewery_location': 'Faicchio, Campania Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '48 Beers 10,737 Ratings',
#   'brewery_ratings': '(3.821)'},
#  {'brewery_name': 'Hammer - Italian Craft Beer',
#   'brewery_location': 'Bergamo, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '56 Beers 34,969 Ratings',
#   'brewery_ratings': '(3.82)'},
#  {'brewery_name': 'LIQUIDA Birrificio Indipendente',
#   'brewery_location': 'Ostellato, Emilia-Romagna Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '51 Beers 8,744 Ratings',
#   'brewery_ratings': '(3.8)'},
#  {'brewery_name': 'Birra MC - 77',
#   'brewery_location': 'Caccamo, Marche Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '86 Beers 16,552 Ratings',
#   'brewery_ratings': '(3.796)'},
#  {'brewery_name': 'AltaVia Agribirrificio',
#   'brewery_location': 'Sassello, Liguria Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '50 Beers 3,681 Ratings',
#   'brewery_ratings': '(3.784)'},
#  {'brewery_name': 'LoverBeer',
#   'brewery_location': 'Marentino, Piemonte Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '49 Beers 66,824 Ratings',
#   'brewery_ratings': '(3.783)'},
#  {'brewery_name': 'Extraomnes',
#   'brewery_location': 'Marnate, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '84 Beers 37,439 Ratings',
#   'brewery_ratings': '(3.77)'},
#  {'brewery_name': 'Shire Brewing',
#   'brewery_location': 'Porciano, Lazio Italy',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '13 Beers 2,416 Ratings',
#   'brewery_ratings': '(3.759)'},
#  {'brewery_name': 'Birra Elvo',
#   'brewery_location': 'Graglia, Piemonte Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '38 Beers 8,867 Ratings',
#   'brewery_ratings': '(3.754)'},
#  {'brewery_name': 'Barley',
#   'brewery_location': 'Maracalagonis, Sardegna Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '44 Beers 8,226 Ratings',
#   'brewery_ratings': '(3.751)'},
#  {'brewery_name': "Birrificio Foglie d'Erba",
#   'brewery_location': 'Forni di Sopra, Friuli Venezia Giulia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '102 Beers 11,020 Ratings',
#   'brewery_ratings': '(3.745)'},
#  {'brewery_name': 'Hilltop Brewery',
#   'brewery_location': 'Bassano Romano, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '75 Beers 14,416 Ratings',
#   'brewery_ratings': '(3.745)'},
#  {'brewery_name': 'Nama Brewing',
#   'brewery_location': 'Treviglio, Lombardy Italy',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '19 Beers 1,216 Ratings',
#   'brewery_ratings': '(3.745)'},
#  {'brewery_name': 'Nix',
#   'brewery_location': 'Pavia, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '8 Beers 3,190 Ratings',
#   'brewery_ratings': '(3.741)'},
#  {'brewery_name': 'Birra del Carrobiolo',
#   'brewery_location': 'Monza, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '111 Beers 10,099 Ratings',
#   'brewery_ratings': '(3.74)'},
#  {'brewery_name': 'Birrificio Porta Bruciata',
#   'brewery_location': 'Rodengo-Saiano, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '34 Beers 9,259 Ratings',
#   'brewery_ratings': '(3.735)'},
#  {'brewery_name': 'Birrificio Bondai',
#   'brewery_location': 'Sutrio, Friuli Venezia Giulia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '16 Beers 2,053 Ratings',
#   'brewery_ratings': '(3.729)'},
#  {'brewery_name': 'OpperBacco',
#   'brewery_location': 'Notaresco, Abruzzo Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '149 Beers 25,859 Ratings',
#   'brewery_ratings': '(3.726)'},
#  {'brewery_name': 'Birrificio Menaresta',
#   'brewery_location': 'Carate Brianza, Lombardia Italy',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '109 Beers 19,456 Ratings',
#   'brewery_ratings': '(3.725)'},
#  {'brewery_name': "Birrificio BioNoc'",
#   'brewery_location': 'Mezzano, Trentino-Alto Adige/Südtirol Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '59 Beers 6,632 Ratings',
#   'brewery_ratings': '(3.723)'},
#  {'brewery_name': 'Eastside Brewing',
#   'brewery_location': 'Latina, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '79 Beers 31,095 Ratings',
#   'brewery_ratings': '(3.723)'},
#  {'brewery_name': "Rebel's Brewery",
#   'brewery_location': 'Roma, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '65 Beers 20,348 Ratings',
#   'brewery_ratings': '(3.72)'},
#  {'brewery_name': 'Buskers Beer',
#   'brewery_location': 'Roma, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '32 Beers 2,503 Ratings',
#   'brewery_ratings': '(3.718)'},
#  {'brewery_name': 'Hop Skin',
#   'brewery_location': 'Curno, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '104 Beers 9,869 Ratings',
#   'brewery_ratings': '(3.718)'},
#  {'brewery_name': 'Kashmir',
#   'brewery_location': 'Filignano, Molise Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '59 Beers 1,467 Ratings',
#   'brewery_ratings': '(3.717)'},
#  {'brewery_name': 'Jungle Juice Brewing',
#   'brewery_location': 'Roma, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '87 Beers 14,898 Ratings',
#   'brewery_ratings': '(3.714)'},
#  {'brewery_name': 'Black Barrels',
#   'brewery_location': 'Turin, Piemonte Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '48 Beers 3,230 Ratings',
#   'brewery_ratings': '(3.713)'},
#  {'brewery_name': 'Ballarak',
#   'brewery_location': 'Palermo, Sicilia Italy',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '25 Beers 1,563 Ratings',
#   'brewery_ratings': '(3.702)'},
#  {'brewery_name': 'Birra Due Tocchi',
#   'brewery_location': 'Parabiago, Lombardia Italy',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '13 Beers 1,176 Ratings',
#   'brewery_ratings': '(3.7)'},
#  {'brewery_name': 'Birrificio Altotevere',
#   'brewery_location': 'San Giustino, Umbria Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '32 Beers 6,574 Ratings',
#   'brewery_ratings': '(3.699)'},
#  {'brewery_name': 'Birrificio Lambrate',
#   'brewery_location': 'Milan, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '133 Beers 94,218 Ratings',
#   'brewery_ratings': '(3.69)'},
#  {'brewery_name': 'South Soul',
#   'brewery_location': 'Francolise, Campania Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '15 Beers 1,603 Ratings',
#   'brewery_ratings': '(3.689)'},
#  {'brewery_name': 'Passion Italian Craft Brewery',
#   'brewery_location': 'Trento, Trentino-Alto Adige/Südtirol Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '26 Beers 3,581 Ratings',
#   'brewery_ratings': '(3.689)'},
#  {'brewery_name': 'Malcantone',
#   'brewery_location': "Ozzano dell'Emilia, Emilia-Romagna Italy",
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '25 Beers 1,448 Ratings',
#   'brewery_ratings': '(3.688)'},
#  {'brewery_name': 'Chianti Brew Fighters',
#   'brewery_location': 'Radda in Chianti, Toscana Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '39 Beers 3,689 Ratings',
#   'brewery_ratings': '(3.687)'},
#  {'brewery_name': 'Terre Di Faul',
#   'brewery_location': 'Viterbo, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '31 Beers 1,699 Ratings',
#   'brewery_ratings': '(3.683)'}]

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
#client.drop_database('brewery_db')
# Define database and collection

db = client.brewery_db
collection_untappd = db.brewery_untappd
collection_untappd.insert_many(untappd)

# %%
import json

with open('brewery_untappd_export_MD.json', 'r', encoding="utf8") as myfile:
    data_untappd = myfile.read()

data= json.loads(data_untappd)
data
# Out:
# [{'_id': {'$oid': '6423495ebd3839367b2e3bba'},
#   'brewery_name': 'Pips Meadery',
#   'brewery_location': 'Beach Park, IL United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '174 Beers 56,661 Ratings',
#   'brewery_ratings': '(4.64)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bbb'},
#   'brewery_name': 'Willow Park Brewing',
#   'brewery_location': 'Bethlehem, PA United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '95 Beers 1,774 Ratings',
#   'brewery_ratings': '(4.558)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bbc'},
#   'brewery_name': 'Brewlihan',
#   'brewery_location': 'Oakland Park, FL United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '78 Beers 3,974 Ratings',
#   'brewery_ratings': '(4.537)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bbd'},
#   'brewery_name': 'Zymarium',
#   'brewery_location': 'Orlando, FL United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '106 Beers 3,935 Ratings',
#   'brewery_ratings': '(4.522)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bbe'},
#   'brewery_name': "Schramm's Mead",
#   'brewery_location': 'Ferndale, MI United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '111 Beers 133,918 Ratings',
#   'brewery_ratings': '(4.52)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bbf'},
#   'brewery_name': 'nebuleus',
#   'brewery_location': 'Portland, OR United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '50 Beers 2,516 Ratings',
#   'brewery_ratings': '(4.486)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc0'},
#   'brewery_name': 'Brujos Brewing',
#   'brewery_location': 'Portland, OR United States',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '14 Beers 4,759 Ratings',
#   'brewery_ratings': '(4.46)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc1'},
#   'brewery_name': 'Boneflower Craft Mead',
#   'brewery_location': 'St. John, IN United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '46 Beers 9,633 Ratings',
#   'brewery_ratings': '(4.45)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc2'},
#   'brewery_name': 'Floodland Brewing',
#   'brewery_location': 'Seattle, WA United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '11 Beers 40,170 Ratings',
#   'brewery_ratings': '(4.44)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc3'},
#   'brewery_name': 'Township Meadery',
#   'brewery_location': 'Odenton, MD United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '61 Beers 1,589 Ratings',
#   'brewery_ratings': '(4.437)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc4'},
#   'brewery_name': 'Side Project Brewing',
#   'brewery_location': 'Saint Louis, MO United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '241 Beers 448,047 Ratings',
#   'brewery_ratings': '(4.434)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc5'},
#   'brewery_name': 'Pye Road Meadworks',
#   'brewery_location': 'Odessa, FL United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '208 Beers 9,614 Ratings',
#   'brewery_ratings': '(4.424)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc6'},
#   'brewery_name': 'Standard Meadery',
#   'brewery_location': 'Villa Park, IL United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '192 Beers 31,894 Ratings',
#   'brewery_ratings': '(4.419)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc7'},
#   'brewery_name': 'Prolyfk Brewing Project',
#   'brewery_location': 'New Bern, NC United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '213 Beers 2,185 Ratings',
#   'brewery_ratings': '(4.413)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc8'},
#   'brewery_name': 'Private Press Brewing',
#   'brewery_location': 'Santa Cruz, CA United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '34 Beers 18,075 Ratings',
#   'brewery_ratings': '(4.413)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bc9'},
#   'brewery_name': 'Mindful Ales',
#   'brewery_location': 'Jersey City, NJ United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '85 Beers 1,537 Ratings',
#   'brewery_ratings': '(4.406)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bca'},
#   'brewery_name': 'Funktastic Meads',
#   'brewery_location': 'Midlothian, VA United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '217 Beers 9,771 Ratings',
#   'brewery_ratings': '(4.403)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bcb'},
#   'brewery_name': 'Fidens Brewing Co',
#   'brewery_location': 'Colonie, NY United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '272 Beers 212,748 Ratings',
#   'brewery_ratings': '(4.393)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bcc'},
#   'brewery_name': 'Smooj',
#   'brewery_location': 'Ann Arbor, MI United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '36 Beers 43,134 Ratings',
#   'brewery_ratings': '(4.39)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bcd'},
#   'brewery_name': 'Weaver Hollow Brewery',
#   'brewery_location': 'Andes, NY United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '51 Beers 3,211 Ratings',
#   'brewery_ratings': '(4.385)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bce'},
#   'brewery_name': 'Root + Branch Brewing',
#   'brewery_location': 'Copiague, NY United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '193 Beers 117,905 Ratings',
#   'brewery_ratings': '(4.369)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bcf'},
#   'brewery_name': 'Garagiste Meadery',
#   'brewery_location': 'Tampa, FL United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '264 Beers 92,830 Ratings',
#   'brewery_ratings': '(4.359)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd0'},
#   'brewery_name': 'Troon Brewing',
#   'brewery_location': 'Hopewell, NJ United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '338 Beers 111,885 Ratings',
#   'brewery_ratings': '(4.355)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd1'},
#   'brewery_name': 'Manic Meadery',
#   'brewery_location': 'Crown Point, IN United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '188 Beers 23,257 Ratings',
#   'brewery_ratings': '(4.354)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd2'},
#   'brewery_name': 'Horus Aged Ales',
#   'brewery_location': 'Oceanside, CA United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '184 Beers 86,655 Ratings',
#   'brewery_ratings': '(4.353)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd3'},
#   'brewery_name': 'Casey Brewing & Blending',
#   'brewery_location': 'Glenwood Springs, CO United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '666 Beers 238,877 Ratings',
#   'brewery_ratings': '(4.341)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd4'},
#   'brewery_name': 'Freak Folk Bier',
#   'brewery_location': 'Waterbury Village Historic District, VT United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '68 Beers 14,950 Ratings',
#   'brewery_ratings': '(4.341)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd5'},
#   'brewery_name': 'House of Fermentology',
#   'brewery_location': 'Burlington, VT United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '40 Beers 13,765 Ratings',
#   'brewery_ratings': '(4.338)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd6'},
#   'brewery_name': 'Tree House Brewing Company',
#   'brewery_location': 'Charlton, MA United States',
#   'brewery_type': 'Regional Brewery',
#   'number_beers': '846 Beers 4,179,910 Ratings',
#   'brewery_ratings': '(4.336)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd7'},
#   'brewery_name': 'Mortalis Brewing Company',
#   'brewery_location': 'Avon, NY United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '529 Beers 333,228 Ratings',
#   'brewery_ratings': '(4.332)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd8'},
#   'brewery_name': 'The Alchemist',
#   'brewery_location': 'Stowe, VT United States',
#   'brewery_type': 'Regional Brewery',
#   'number_beers': '112 Beers 728,351 Ratings',
#   'brewery_ratings': '(4.332)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bd9'},
#   'brewery_name': 'Hex Meadery',
#   'brewery_location': 'Kaukauna, WI United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '47 Beers 1,188 Ratings',
#   'brewery_ratings': '(4.328)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bda'},
#   'brewery_name': 'Hill Farmstead Brewery',
#   'brewery_location': 'Greensboro, VT United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '341 Beers 1,240,201 Ratings',
#   'brewery_ratings': '(4.319)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bdb'},
#   'brewery_name': 'The Answer',
#   'brewery_location': 'Richmond, VA United States',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '1,876 Beers 566,986 Ratings',
#   'brewery_ratings': '(4.317)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bdc'},
#   'brewery_name': 'Honey Pot Meadery',
#   'brewery_location': 'Anaheim, CA United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '298 Beers 21,579 Ratings',
#   'brewery_ratings': '(4.303)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bdd'},
#   'brewery_name': 'Amalgam Brewing',
#   'brewery_location': 'Denver, CO United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '62 Beers 5,182 Ratings',
#   'brewery_ratings': '(4.302)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bde'},
#   'brewery_name': 'Monkish Brewing Co.',
#   'brewery_location': 'Torrance, CA United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '826 Beers 945,300 Ratings',
#   'brewery_ratings': '(4.301)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bdf'},
#   'brewery_name': 'CLAG Brewing Company',
#   'brewery_location': 'Sandusky, OH United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '181 Beers 34,343 Ratings',
#   'brewery_ratings': '(4.289)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be0'},
#   'brewery_name': 'Wunderkammer Biermanufaktur',
#   'brewery_location': 'Albany, VT United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '26 Beers 3,271 Ratings',
#   'brewery_ratings': '(4.286)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be1'},
#   'brewery_name': 'Corporate Ladder Brewing Company',
#   'brewery_location': 'Palmetto, FL United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '518 Beers 86,248 Ratings',
#   'brewery_ratings': '(4.284)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be2'},
#   'brewery_name': 'Ceiba',
#   'brewery_location': 'Miami, FL United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '89 Beers 1,316 Ratings',
#   'brewery_ratings': '(4.282)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be3'},
#   'brewery_name': 'Electric Brewing Co.',
#   'brewery_location': 'Murrieta, CA United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '422 Beers 110,930 Ratings',
#   'brewery_ratings': '(4.282)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be4'},
#   'brewery_name': 'Three Chiefs Brewing Co.',
#   'brewery_location': 'Los Angeles, CA United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '74 Beers 10,558 Ratings',
#   'brewery_ratings': '(4.281)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be5'},
#   'brewery_name': 'Shared',
#   'brewery_location': 'Saint Louis, MO United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '130 Beers 111,022 Ratings',
#   'brewery_ratings': '(4.276)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be6'},
#   'brewery_name': 'Obercreek Brewing Company',
#   'brewery_location': 'Wappingers Falls, NY United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '262 Beers 18,747 Ratings',
#   'brewery_ratings': '(4.275)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be7'},
#   'brewery_name': 'BKS Artisan Ales',
#   'brewery_location': 'Kansas City, MO United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '556 Beers 75,415 Ratings',
#   'brewery_ratings': '(4.274)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be8'},
#   'brewery_name': 'Wax Wings Brewing Company',
#   'brewery_location': 'Kalamazoo, MI United States',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '352 Beers 71,206 Ratings',
#   'brewery_ratings': '(4.271)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3be9'},
#   'brewery_name': 'de Garde Brewing',
#   'brewery_location': 'Tillamook, OR United States',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '337 Beers 388,815 Ratings',
#   'brewery_ratings': '(4.266)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3bea'},
#   'brewery_name': 'Juicy Brewing Co',
#   'brewery_location': 'Herndon, VA United States',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '168 Beers 10,972 Ratings',
#   'brewery_ratings': '(4.262)'},
#  {'_id': {'$oid': '6423495ebd3839367b2e3beb'},
#   'brewery_name': "Misbeehavin' Meads",
#   'brewery_location': 'Valparaiso, IN United States',
#   'brewery_type': 'Meadery',
#   'number_beers': '233 Beers 31,588 Ratings',
#   'brewery_ratings': '(4.259)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bee'},
#   'brewery_name': 'Huisstekerij H.ertie',
#   'brewery_location': 'Duisburg, Nordrhein-Westfalen Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '109 Beers 4,792 Ratings',
#   'brewery_ratings': '(4.268)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bef'},
#   'brewery_name': 'ATELIER VRAI',
#   'brewery_location': 'Heidelbach, Hessen Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '59 Beers 64,726 Ratings',
#   'brewery_ratings': '(4.026)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf0'},
#   'brewery_name': 'Tyrell BrauKunstAtelier',
#   'brewery_location': 'Börnicke, Brandenburg Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '9 Beers 1,323 Ratings',
#   'brewery_ratings': '(3.981)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf1'},
#   'brewery_name': 'Cool Cats In Town',
#   'brewery_location': 'Hamburg, Hamburg Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '70 Beers 1,133 Ratings',
#   'brewery_ratings': '(3.977)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf2'},
#   'brewery_name': 'Lonesome Oak Brewing',
#   'brewery_location': 'Braunschweig, Niedersachsen Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '91 Beers 1,562 Ratings',
#   'brewery_ratings': '(3.966)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf3'},
#   'brewery_name': 'BrewHeart',
#   'brewery_location': 'Gundelfingen an der Donau, Bayern Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '68 Beers 100,519 Ratings',
#   'brewery_ratings': '(3.963)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf4'},
#   'brewery_name': 'Blech.Brut',
#   'brewery_location': 'Bamberg, Bayern Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '47 Beers 89,234 Ratings',
#   'brewery_ratings': '(3.933)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf5'},
#   'brewery_name': 'Sudden Death Brewing Co.',
#   'brewery_location': 'Lübeck, Schleswig-Holstein Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '137 Beers 269,128 Ratings',
#   'brewery_ratings': '(3.929)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf6'},
#   'brewery_name': 'FUERST WIACEK',
#   'brewery_location': 'Berlin, Berlin Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '197 Beers 294,579 Ratings',
#   'brewery_ratings': '(3.922)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf7'},
#   'brewery_name': 'FrauGruber Brewing',
#   'brewery_location': 'Gundelfingen a.d.Donau, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '185 Beers 389,910 Ratings',
#   'brewery_ratings': '(3.891)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf8'},
#   'brewery_name': 'Schwarze Rose',
#   'brewery_location': 'Mainz, Rheinland-Pfalz Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '59 Beers 52,686 Ratings',
#   'brewery_ratings': '(3.875)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bf9'},
#   'brewery_name': 'Kemker Kultuur (Brauerei J. Kemker)',
#   'brewery_location': 'Everswinkel, Nordrhein-Westfalen Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '111 Beers 19,175 Ratings',
#   'brewery_ratings': '(3.859)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bfa'},
#   'brewery_name': 'Ammergauer Maxbräu',
#   'brewery_location': 'Germany',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '26 Beers 1,329 Ratings',
#   'brewery_ratings': '(3.85)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bfb'},
#   'brewery_name': 'Protokoll Brewery',
#   'brewery_location': 'Berlin, Berlin Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '30 Beers 24,853 Ratings',
#   'brewery_ratings': '(3.847)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bfc'},
#   'brewery_name': 'Kulmbacher Kommunbräu',
#   'brewery_location': 'Kulmbach, Bayern Germany',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '24 Beers 1,911 Ratings',
#   'brewery_ratings': '(3.829)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bfd'},
#   'brewery_name': 'Klosterbrauerei Kreuzberg',
#   'brewery_location': 'Bischofsheim a.d.Rhön, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '10 Beers 2,748 Ratings',
#   'brewery_ratings': '(3.828)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bfe'},
#   'brewery_name': 'Lieber Waldi',
#   'brewery_location': 'Cologne, Nordrhein-Westfalen Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '38 Beers 10,685 Ratings',
#   'brewery_ratings': '(3.817)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3bff'},
#   'brewery_name': 'Bier Rebell',
#   'brewery_location': 'Rostock, Mecklenburg-Vorpommern Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '8 Beers 1,054 Ratings',
#   'brewery_ratings': '(3.812)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c00'},
#   'brewery_name': 'YAYLE',
#   'brewery_location': 'Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '6 Beers 1,833 Ratings',
#   'brewery_ratings': '(3.809)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c01'},
#   'brewery_name': 'Bräugier Craftbier',
#   'brewery_location': 'Berlin, Berlin Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '107 Beers 31,209 Ratings',
#   'brewery_ratings': '(3.791)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c02'},
#   'brewery_name': 'Sonnen-Bräu Mürsbach',
#   'brewery_location': 'Mürsbach, Bayern Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '23 Beers 1,893 Ratings',
#   'brewery_ratings': '(3.787)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c03'},
#   'brewery_name': 'Steinbach Bräu',
#   'brewery_location': 'Erlangen, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '51 Beers 4,749 Ratings',
#   'brewery_ratings': '(3.784)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c04'},
#   'brewery_name': 'Brauerei Zehendner',
#   'brewery_location': 'Burgebrach, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '8 Beers 12,727 Ratings',
#   'brewery_ratings': '(3.776)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c05'},
#   'brewery_name': 'Griesmüllers Altstadtbrauerei',
#   'brewery_location': 'Ingolstadt, Bayern Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '38 Beers 1,286 Ratings',
#   'brewery_ratings': '(3.776)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c06'},
#   'brewery_name': 'Malto Brewpub',
#   'brewery_location': 'Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '32 Beers 5,896 Ratings',
#   'brewery_ratings': '(3.756)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c07'},
#   'brewery_name': 'Handwerksbrauerei Hennings',
#   'brewery_location': 'Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '26 Beers 1,348 Ratings',
#   'brewery_ratings': '(3.754)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c08'},
#   'brewery_name': 'Liquid Story Brewing Co.',
#   'brewery_location': 'Braunschweig, Niedersachsen Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '21 Beers 4,091 Ratings',
#   'brewery_ratings': '(3.751)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c09'},
#   'brewery_name': 'Gorilla Cervecería Berlin',
#   'brewery_location': 'Berlin, Berlin Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '33 Beers 13,083 Ratings',
#   'brewery_ratings': '(3.744)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c0a'},
#   'brewery_name': 'Unverhopft',
#   'brewery_location': 'Berlin, Berlin Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '31 Beers 12,856 Ratings',
#   'brewery_ratings': '(3.742)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c0b'},
#   'brewery_name': 'Hopfengut № 20',
#   'brewery_location': 'Siggenweiler, Baden-Württemberg Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '25 Beers 3,911 Ratings',
#   'brewery_ratings': '(3.742)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c0c'},
#   'brewery_name': 'Uetzinger Metzgerbräu',
#   'brewery_location': 'Bad Staffelstein, Bayern Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '5 Beers 1,299 Ratings',
#   'brewery_ratings': '(3.739)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c0d'},
#   'brewery_name': 'Hausbrauerei Feierling',
#   'brewery_location': 'Freiburg, Baden-Württemberg Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '8 Beers 4,149 Ratings',
#   'brewery_ratings': '(3.737)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c0e'},
#   'brewery_name': 'Grebhans Bier',
#   'brewery_location': 'Bremen, Bremen Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '149 Beers 2,623 Ratings',
#   'brewery_ratings': '(3.734)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c0f'},
#   'brewery_name': 'Schneider Weisse G. Schneider & Sohn',
#   'brewery_location': 'Kelheim, Bayern Germany',
#   'brewery_type': 'Regional Brewery',
#   'number_beers': '13 Beers 617,725 Ratings',
#   'brewery_ratings': '(3.731)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c10'},
#   'brewery_name': 'Higgins Ale Works',
#   'brewery_location': '80333, München, Bayern Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '63 Beers 3,345 Ratings',
#   'brewery_ratings': '(3.727)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c11'},
#   'brewery_name': 'Dr. Fritz Briem',
#   'brewery_location': 'Au in der Hallertau, Bayern Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '5 Beers 30,160 Ratings',
#   'brewery_ratings': '(3.726)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c12'},
#   'brewery_name': 'Bayerische Staatsbrauerei Weihenstephan',
#   'brewery_location': 'Freising, Bayern Germany',
#   'brewery_type': 'Regional Brewery',
#   'number_beers': '22 Beers 1,085,450 Ratings',
#   'brewery_ratings': '(3.716)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c13'},
#   'brewery_name': 'Wittorfer Brauerei Neumünster',
#   'brewery_location': 'Neumünster, Schleswig-Holstein Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '102 Beers 26,260 Ratings',
#   'brewery_ratings': '(3.709)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c14'},
#   'brewery_name': 'Ayinger Privatbrauerei',
#   'brewery_location': 'Aying, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '22 Beers 700,680 Ratings',
#   'brewery_ratings': '(3.709)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c15'},
#   'brewery_name': 'Gasthofbrauerei Will',
#   'brewery_location': 'Schederndorf, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '14 Beers 2,318 Ratings',
#   'brewery_ratings': '(3.708)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c16'},
#   'brewery_name': 'Paulaner Nockherberg',
#   'brewery_location': 'Munich, Bayern Germany',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '13 Beers 1,796 Ratings',
#   'brewery_ratings': '(3.707)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c17'},
#   'brewery_name': 'Blech.Brut 8 Bit',
#   'brewery_location': 'Bamberg, Bayern Germany',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '8 Beers 3,530 Ratings',
#   'brewery_ratings': '(3.703)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c18'},
#   'brewery_name': 'Griesbräu zu Murnau',
#   'brewery_location': 'Murnau, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '32 Beers 2,275 Ratings',
#   'brewery_ratings': '(3.702)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c19'},
#   'brewery_name': "Cliff's Brauwerk",
#   'brewery_location': 'Leipzig, Sachsen Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '98 Beers 2,909 Ratings',
#   'brewery_ratings': '(3.699)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c1a'},
#   'brewery_name': 'True Brew Brewing Co.',
#   'brewery_location': 'Munich, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '76 Beers 41,043 Ratings',
#   'brewery_ratings': '(3.693)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c1b'},
#   'brewery_name': 'Brauerei Michael Plank',
#   'brewery_location': 'Laaber, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '26 Beers 16,038 Ratings',
#   'brewery_ratings': '(3.69)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c1c'},
#   'brewery_name': 'Brauerei Roppelt Stiebarlimbach',
#   'brewery_location': 'Hallerndorf, Bayern Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '8 Beers 2,864 Ratings',
#   'brewery_ratings': '(3.688)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c1d'},
#   'brewery_name': 'Simian Ales',
#   'brewery_location': 'Elmshorn, Schleswig-Holstein Germany',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '24 Beers 9,935 Ratings',
#   'brewery_ratings': '(3.687)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c1e'},
#   'brewery_name': 'Darmstädter Ratskeller Hausbrauerei',
#   'brewery_location': 'Darmstadt, Hessen Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '5 Beers 1,962 Ratings',
#   'brewery_ratings': '(3.686)'},
#  {'_id': {'$oid': '64234bb5bd3839367b2e3c1f'},
#   'brewery_name': 'Schwetzinger Brauhaus zum Ritter',
#   'brewery_location': 'Germany',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '5 Beers 1,065 Ratings',
#   'brewery_ratings': '(3.685)'},
#  {'_id': {'$oid': '642359ed99268f500774d643'},
#   'brewery_name': 'Sergacore Brewery',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '21 Beers 6,308 Ratings',
#   'brewery_ratings': '(4.385)'},
#  {'_id': {'$oid': '642359ed99268f500774d644'},
#   'brewery_name': 'Alcove',
#   'brewery_location': 'Vladimir, Vladimir Oblast Russia',
#   'brewery_type': 'Meadery',
#   'number_beers': '10 Beers 3,280 Ratings',
#   'brewery_ratings': '(4.338)'},
#  {'_id': {'$oid': '642359ed99268f500774d645'},
#   'brewery_name': 'КУЛИNAR',
#   'brewery_location': 'Moscow, Moscow Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '10 Beers 6,733 Ratings',
#   'brewery_ratings': '(4.301)'},
#  {'_id': {'$oid': '642359ed99268f500774d646'},
#   'brewery_name': 'Bugtown Project',
#   'brewery_location': 'Russia',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '12 Beers 2,900 Ratings',
#   'brewery_ratings': '(4.298)'},
#  {'_id': {'$oid': '642359ed99268f500774d647'},
#   'brewery_name': 'Big Pot',
#   'brewery_location': 'Rostov-on-Don, Rostov Oblast Russia',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '55 Beers 5,186 Ratings',
#   'brewery_ratings': '(4.239)'},
#  {'_id': {'$oid': '642359ed99268f500774d648'},
#   'brewery_name': 'Api Del Bernini',
#   'brewery_location': 'Russia',
#   'brewery_type': 'Meadery',
#   'number_beers': '5 Beers 1,075 Ratings',
#   'brewery_ratings': '(4.213)'},
#  {'_id': {'$oid': '642359ed99268f500774d649'},
#   'brewery_name': 'Meadiaeval Bardcore',
#   'brewery_location': 'Russia',
#   'brewery_type': 'Meadery',
#   'number_beers': '17 Beers 1,209 Ratings',
#   'brewery_ratings': '(4.163)'},
#  {'_id': {'$oid': '642359ed99268f500774d64a'},
#   'brewery_name': 'Coma Brewery',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '40 Beers 28,927 Ratings',
#   'brewery_ratings': '(4.141)'},
#  {'_id': {'$oid': '642359ed99268f500774d64b'},
#   'brewery_name': 'Andreev Ciderworks',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Cidery',
#   'number_beers': '37 Beers 2,883 Ratings',
#   'brewery_ratings': '(4.133)'},
#  {'_id': {'$oid': '642359ed99268f500774d64c'},
#   'brewery_name': 'Ashram Cider',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Cidery',
#   'number_beers': '82 Beers 7,591 Ratings',
#   'brewery_ratings': '(4.124)'},
#  {'_id': {'$oid': '642359ed99268f500774d64d'},
#   'brewery_name': 'Steppe & Wind Meadery (Степь и Ветер)',
#   'brewery_location': 'Orenburg, Оренбургская область Russia',
#   'brewery_type': 'Meadery',
#   'number_beers': '92 Beers 66,504 Ratings',
#   'brewery_ratings': '(4.118)'},
#  {'_id': {'$oid': '642359ed99268f500774d64e'},
#   'brewery_name': 'Double A Brewing',
#   'brewery_location': 'Оболенск, Московская область Russia',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '39 Beers 11,745 Ratings',
#   'brewery_ratings': '(4.112)'},
#  {'_id': {'$oid': '642359ed99268f500774d64f'},
#   'brewery_name': 'DIETA / ДИЕТА',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '111 Beers 56,424 Ratings',
#   'brewery_ratings': '(4.103)'},
#  {'_id': {'$oid': '642359ed99268f500774d650'},
#   'brewery_name': 'Atlas Meadery',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Meadery',
#   'number_beers': '14 Beers 2,040 Ratings',
#   'brewery_ratings': '(4.071)'},
#  {'_id': {'$oid': '642359ed99268f500774d651'},
#   'brewery_name': 'Spontanist',
#   'brewery_location': 'Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '9 Beers 1,246 Ratings',
#   'brewery_ratings': '(4.039)'},
#  {'_id': {'$oid': '642359ed99268f500774d652'},
#   'brewery_name': 'Zagovor Brewery',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '249 Beers 434,606 Ratings',
#   'brewery_ratings': '(4.022)'},
#  {'_id': {'$oid': '642359ed99268f500774d653'},
#   'brewery_name': 'Share House',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '109 Beers 4,154 Ratings',
#   'brewery_ratings': '(4.022)'},
#  {'_id': {'$oid': '642359ed99268f500774d654'},
#   'brewery_name': 'Stamm Brewing',
#   'brewery_location': 'Красная Пахра, Москва Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '188 Beers 348,071 Ratings',
#   'brewery_ratings': '(4.021)'},
#  {'_id': {'$oid': '642359ed99268f500774d655'},
#   'brewery_name': 'Outline Brewing',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '12 Beers 1,951 Ratings',
#   'brewery_ratings': '(4.014)'},
#  {'_id': {'$oid': '642359ed99268f500774d656'},
#   'brewery_name': 'DaDa Cider',
#   'brewery_location': 'Serebryanyye Prudy, Московская область Russia',
#   'brewery_type': 'Cidery',
#   'number_beers': '13 Beers 10,218 Ratings',
#   'brewery_ratings': '(4.009)'},
#  {'_id': {'$oid': '642359ed99268f500774d657'},
#   'brewery_name': 'Wild Lab',
#   'brewery_location': 'Moscow, Moscow Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '114 Beers 78,652 Ratings',
#   'brewery_ratings': '(3.991)'},
#  {'_id': {'$oid': '642359ed99268f500774d658'},
#   'brewery_name': 'Медоварня B-side',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Meadery',
#   'number_beers': '5 Beers 2,119 Ratings',
#   'brewery_ratings': '(3.991)'},
#  {'_id': {'$oid': '642359ed99268f500774d659'},
#   'brewery_name': 'Nordic Meadery',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Meadery',
#   'number_beers': '22 Beers 5,218 Ratings',
#   'brewery_ratings': '(3.986)'},
#  {'_id': {'$oid': '642359ed99268f500774d65a'},
#   'brewery_name': 'TryWild',
#   'brewery_location': 'Izhevsk, Udmurt Republic Russia',
#   'brewery_type': 'Cidery',
#   'number_beers': '28 Beers 1,502 Ratings',
#   'brewery_ratings': '(3.986)'},
#  {'_id': {'$oid': '642359ed99268f500774d65b'},
#   'brewery_name': 'Big Village Brewery',
#   'brewery_location': 'Krasnodar, Краснодарский край Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '435 Beers 251,622 Ratings',
#   'brewery_ratings': '(3.984)'},
#  {'_id': {'$oid': '642359ed99268f500774d65c'},
#   'brewery_name': 'GUSI',
#   'brewery_location': "Novosibirsk, Novosibirskaya oblast' Russia",
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '154 Beers 27,221 Ratings',
#   'brewery_ratings': '(3.979)'},
#  {'_id': {'$oid': '642359ed99268f500774d65d'},
#   'brewery_name': 'Applehead',
#   'brewery_location': 'Staraya Russa, Новгородская область Russia',
#   'brewery_type': 'Cidery',
#   'number_beers': '17 Beers 1,848 Ratings',
#   'brewery_ratings': '(3.971)'},
#  {'_id': {'$oid': '642359ed99268f500774d65e'},
#   'brewery_name': 'Magic Mess',
#   'brewery_location': 'Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '76 Beers 13,357 Ratings',
#   'brewery_ratings': '(3.968)'},
#  {'_id': {'$oid': '642359ed99268f500774d65f'},
#   'brewery_name': 'Та-Та',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '44 Beers 16,628 Ratings',
#   'brewery_ratings': '(3.966)'},
#  {'_id': {'$oid': '642359ed99268f500774d660'},
#   'brewery_name': '4BREWERS',
#   'brewery_location': "Vladimir, Vladimirskaya oblast' Russia",
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '313 Beers 238,851 Ratings',
#   'brewery_ratings': '(3.962)'},
#  {'_id': {'$oid': '642359ed99268f500774d661'},
#   'brewery_name': 'Заповедник',
#   'brewery_location': 'Pushkinskiye Gory, Псковская область Russia',
#   'brewery_type': 'Cidery',
#   'number_beers': '23 Beers 10,030 Ratings',
#   'brewery_ratings': '(3.962)'},
#  {'_id': {'$oid': '642359ed99268f500774d662'},
#   'brewery_name': 'Fable Meadery',
#   'brewery_location': 'Russia',
#   'brewery_type': 'Meadery',
#   'number_beers': '20 Beers 2,919 Ratings',
#   'brewery_ratings': '(3.959)'},
#  {'_id': {'$oid': '642359ed99268f500774d663'},
#   'brewery_name': 'Plague Brew',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '202 Beers 38,630 Ratings',
#   'brewery_ratings': '(3.959)'},
#  {'_id': {'$oid': '642359ed99268f500774d664'},
#   'brewery_name': 'SINDROM Brewery',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '69 Beers 5,842 Ratings',
#   'brewery_ratings': '(3.95)'},
#  {'_id': {'$oid': '642359ed99268f500774d665'},
#   'brewery_name': 'NONSense Brewery',
#   'brewery_location': 'Russia',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '33 Beers 1,690 Ratings',
#   'brewery_ratings': '(3.95)'},
#  {'_id': {'$oid': '642359ed99268f500774d666'},
#   'brewery_name': 'Ame Wild Freaks',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '27 Beers 4,319 Ratings',
#   'brewery_ratings': '(3.948)'},
#  {'_id': {'$oid': '642359ed99268f500774d667'},
#   'brewery_name': 'Oka River',
#   'brewery_location': 'Алеканово, Рязанская область Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '164 Beers 16,882 Ratings',
#   'brewery_ratings': '(3.948)'},
#  {'_id': {'$oid': '642359ed99268f500774d668'},
#   'brewery_name': 'Sabotage',
#   'brewery_location': 'Perm, Permskiy kray Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '104 Beers 80,252 Ratings',
#   'brewery_ratings': '(3.945)'},
#  {'_id': {'$oid': '642359ed99268f500774d669'},
#   'brewery_name': 'SALIWA',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '23 Beers 4,835 Ratings',
#   'brewery_ratings': '(3.941)'},
#  {'_id': {'$oid': '642359ed99268f500774d66a'},
#   'brewery_name': 'Cosmic City',
#   'brewery_location': 'Korolyov, Московская область Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '113 Beers 32,012 Ratings',
#   'brewery_ratings': '(3.939)'},
#  {'_id': {'$oid': '642359ed99268f500774d66b'},
#   'brewery_name': 'Black Cat Brewery',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '157 Beers 64,548 Ratings',
#   'brewery_ratings': '(3.938)'},
#  {'_id': {'$oid': '642359ed99268f500774d66c'},
#   'brewery_name': 'Samovar Brew',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '88 Beers 7,382 Ratings',
#   'brewery_ratings': '(3.937)'},
#  {'_id': {'$oid': '642359ed99268f500774d66d'},
#   'brewery_name': 'GAS Brew',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '250 Beers 37,085 Ratings',
#   'brewery_ratings': '(3.936)'},
#  {'_id': {'$oid': '642359ed99268f500774d66e'},
#   'brewery_name': 'Пивная Диета (Beer Diet)',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '24 Beers 10,837 Ratings',
#   'brewery_ratings': '(3.934)'},
#  {'_id': {'$oid': '642359ed99268f500774d66f'},
#   'brewery_name': 'Time Bomb Brewery',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '61 Beers 18,834 Ratings',
#   'brewery_ratings': '(3.925)'},
#  {'_id': {'$oid': '642359ed99268f500774d670'},
#   'brewery_name': 'DorBeer',
#   'brewery_location': 'Solnechnogorsk, Московская область Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '30 Beers 1,180 Ratings',
#   'brewery_ratings': '(3.925)'},
#  {'_id': {'$oid': '642359ed99268f500774d671'},
#   'brewery_name': 'Gravity Project',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Cidery',
#   'number_beers': '29 Beers 14,438 Ratings',
#   'brewery_ratings': '(3.924)'},
#  {'_id': {'$oid': '642359ed99268f500774d672'},
#   'brewery_name': 'Red Rocket Brewery',
#   'brewery_location': 'Yekaterinburg, Sverdlovsk Oblast Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '113 Beers 54,589 Ratings',
#   'brewery_ratings': '(3.922)'},
#  {'_id': {'$oid': '642359ed99268f500774d673'},
#   'brewery_name': 'Hophead Brewery',
#   'brewery_location': 'Saint Petersburg, Санкт-Петербург Russia',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '226 Beers 123,059 Ratings',
#   'brewery_ratings': '(3.921)'},
#  {'_id': {'$oid': '642359ed99268f500774d674'},
#   'brewery_name': 'Selfmade Brewery',
#   'brewery_location': 'Moscow, Москва Russia',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '248 Beers 255,026 Ratings',
#   'brewery_ratings': '(3.92)'},
#  {'_id': {'$oid': '64235b8b99268f500774d676'},
#   'brewery_name': "Emperor's Brewery",
#   'brewery_location': 'Coalville, Leicestershire England',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '49 Beers 1,639 Ratings',
#   'brewery_ratings': '(4.444)'},
#  {'_id': {'$oid': '64235b8b99268f500774d677'},
#   'brewery_name': 'Cult Of Oak',
#   'brewery_location': 'Netherton, West Midlands England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '24 Beers 1,597 Ratings',
#   'brewery_ratings': '(4.276)'},
#  {'_id': {'$oid': '64235b8b99268f500774d678'},
#   'brewery_name': 'Mills Brewing',
#   'brewery_location': 'Berkeley, Gloucestershire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '69 Beers 18,053 Ratings',
#   'brewery_ratings': '(4.182)'},
#  {'_id': {'$oid': '64235b8b99268f500774d679'},
#   'brewery_name': 'Blender.',
#   'brewery_location': 'England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '12 Beers 2,734 Ratings',
#   'brewery_ratings': '(4.123)'},
#  {'_id': {'$oid': '64235b8b99268f500774d67a'},
#   'brewery_name': 'Old Chimneys Brewery',
#   'brewery_location': 'Market Weston, Suffolk England',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '62 Beers 7,110 Ratings',
#   'brewery_ratings': '(4.057)'},
#  {'_id': {'$oid': '64235b8b99268f500774d67b'},
#   'brewery_name': 'Verdant Brewing Co',
#   'brewery_location': 'Penryn, Cornwall England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '194 Beers 796,714 Ratings',
#   'brewery_ratings': '(4.055)'},
#  {'_id': {'$oid': '64235b8b99268f500774d67c'},
#   'brewery_name': 'Makemake',
#   'brewery_location': 'Portsmouth, Portsmouth England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '84 Beers 7,753 Ratings',
#   'brewery_ratings': '(4.015)'},
#  {'_id': {'$oid': '64235b8b99268f500774d67d'},
#   'brewery_name': 'FireRock Brewing Co',
#   'brewery_location': 'Sutton in Ashfield, England England',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '59 Beers 1,271 Ratings',
#   'brewery_ratings': '(4.014)'},
#  {'_id': {'$oid': '64235b8b99268f500774d67e'},
#   'brewery_name': 'Woodland Brewing',
#   'brewery_location': '14 Market Street, England England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '82 Beers 1,550 Ratings',
#   'brewery_ratings': '(4.013)'},
#  {'_id': {'$oid': '64235b8b99268f500774d67f'},
#   'brewery_name': 'Nothing Bound Brewing Co',
#   'brewery_location': 'Heightington, Worcestershire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '74 Beers 8,364 Ratings',
#   'brewery_ratings': '(4.01)'},
#  {'_id': {'$oid': '64235b8b99268f500774d680'},
#   'brewery_name': 'Accidental Brewery',
#   'brewery_location': 'Lancaster, Lancashire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '76 Beers 4,013 Ratings',
#   'brewery_ratings': '(4.008)'},
#  {'_id': {'$oid': '64235b8b99268f500774d681'},
#   'brewery_name': 'Low Key Barrel Project',
#   'brewery_location': 'Ashford, Kent England',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '33 Beers 2,950 Ratings',
#   'brewery_ratings': '(4.006)'},
#  {'_id': {'$oid': '64235b8b99268f500774d682'},
#   'brewery_name': 'Dolphin Brewery',
#   'brewery_location': 'Reading, Reading England',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '23 Beers 2,326 Ratings',
#   'brewery_ratings': '(4.004)'},
#  {'_id': {'$oid': '64235b8b99268f500774d683'},
#   'brewery_name': 'Neon Raptor Brewing Co.',
#   'brewery_location': 'Nottingham, City of Nottingham England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '246 Beers 224,588 Ratings',
#   'brewery_ratings': '(3.996)'},
#  {'_id': {'$oid': '64235b8b99268f500774d684'},
#   'brewery_name': 'Azvex Brewing Company',
#   'brewery_location': 'Liverpool, Merseyside England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '105 Beers 78,886 Ratings',
#   'brewery_ratings': '(3.992)'},
#  {'_id': {'$oid': '64235b8b99268f500774d685'},
#   'brewery_name': 'DEYA Brewing Company',
#   'brewery_location': 'Cheltenham, Gloucestershire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '312 Beers 494,006 Ratings',
#   'brewery_ratings': '(3.989)'},
#  {'_id': {'$oid': '64235b8b99268f500774d686'},
#   'brewery_name': 'Gravity Well Brewing Co',
#   'brewery_location': 'Leyton, London England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '119 Beers 14,562 Ratings',
#   'brewery_ratings': '(3.973)'},
#  {'_id': {'$oid': '64235b8b99268f500774d687'},
#   'brewery_name': 'Track Brewing Company',
#   'brewery_location': 'Manchester, Greater Manchester England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '292 Beers 319,997 Ratings',
#   'brewery_ratings': '(3.972)'},
#  {'_id': {'$oid': '64235b8b99268f500774d688'},
#   'brewery_name': 'Brewis Beer Co',
#   'brewery_location': 'Amble, Northumberland England',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '58 Beers 1,210 Ratings',
#   'brewery_ratings': '(3.972)'},
#  {'_id': {'$oid': '64235b8b99268f500774d689'},
#   'brewery_name': 'Pipeline Brewing Co',
#   'brewery_location': 'Saint Agnes, Cornwall England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '64 Beers 10,717 Ratings',
#   'brewery_ratings': '(3.971)'},
#  {'_id': {'$oid': '64235b8b99268f500774d68a'},
#   'brewery_name': 'Beak Brewery',
#   'brewery_location': 'Lewes, East Sussex England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '139 Beers 100,826 Ratings',
#   'brewery_ratings': '(3.962)'},
#  {'_id': {'$oid': '64235b8b99268f500774d68b'},
#   'brewery_name': 'Cloudwater Brew Co.',
#   'brewery_location': 'Manchester, Greater Manchester England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '464 Beers 1,413,980 Ratings',
#   'brewery_ratings': '(3.961)'},
#  {'_id': {'$oid': '64235b8b99268f500774d68c'},
#   'brewery_name': 'Field Recordings',
#   'brewery_location': 'Leeds, West Yorkshire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '5 Beers 3,178 Ratings',
#   'brewery_ratings': '(3.952)'},
#  {'_id': {'$oid': '64235b8b99268f500774d68d'},
#   'brewery_name': 'Tartarus Beers',
#   'brewery_location': 'Leeds, West Yorkshire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '66 Beers 20,655 Ratings',
#   'brewery_ratings': '(3.948)'},
#  {'_id': {'$oid': '64235b8b99268f500774d68e'},
#   'brewery_name': 'Three Hills Brewing',
#   'brewery_location': 'Woodford, Northamptonshire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '350 Beers 81,640 Ratings',
#   'brewery_ratings': '(3.935)'},
#  {'_id': {'$oid': '64235b8b99268f500774d68f'},
#   'brewery_name': 'By The River Brew Co',
#   'brewery_location': 'Gateshead, Tyne and Wear England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '35 Beers 18,836 Ratings',
#   'brewery_ratings': '(3.932)'},
#  {'_id': {'$oid': '64235b8b99268f500774d690'},
#   'brewery_name': 'Saint Mars Of The Desert',
#   'brewery_location': 'Sheffield, South Yorkshire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '108 Beers 38,415 Ratings',
#   'brewery_ratings': '(3.924)'},
#  {'_id': {'$oid': '64235b8b99268f500774d691'},
#   'brewery_name': 'Knight Life Brewing Ltd',
#   'brewery_location': 'Bournemouth, England England',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '40 Beers 1,406 Ratings',
#   'brewery_ratings': '(3.921)'},
#  {'_id': {'$oid': '64235b8b99268f500774d692'},
#   'brewery_name': 'Wylam',
#   'brewery_location': 'Newcastle upon Tyne, Tyne and Wear England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '213 Beers 491,828 Ratings',
#   'brewery_ratings': '(3.918)'},
#  {'_id': {'$oid': '64235b8b99268f500774d693'},
#   'brewery_name': 'Little Pomona',
#   'brewery_location': 'Bromyard, Herefordshire England',
#   'brewery_type': 'Cidery',
#   'number_beers': '63 Beers 2,324 Ratings',
#   'brewery_ratings': '(3.917)'},
#  {'_id': {'$oid': '64235b8b99268f500774d694'},
#   'brewery_name': 'Pomona Island Brew Co.',
#   'brewery_location': 'Salford, Greater Manchester England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '392 Beers 278,046 Ratings',
#   'brewery_ratings': '(3.914)'},
#  {'_id': {'$oid': '64235b8b99268f500774d695'},
#   'brewery_name': 'GlassHouse Beer Co',
#   'brewery_location': 'Birmingham, West Midlands Combined Authority England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '190 Beers 52,096 Ratings',
#   'brewery_ratings': '(3.908)'},
#  {'_id': {'$oid': '64235b8b99268f500774d696'},
#   'brewery_name': 'Crossover Blendery',
#   'brewery_location': 'Hitchin, Hertfordshire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '31 Beers 4,781 Ratings',
#   'brewery_ratings': '(3.908)'},
#  {'_id': {'$oid': '64235b8b99268f500774d697'},
#   'brewery_name': 'Rivington Brewing Co',
#   'brewery_location': 'Rivington, Lancashire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '153 Beers 65,251 Ratings',
#   'brewery_ratings': '(3.904)'},
#  {'_id': {'$oid': '64235b8b99268f500774d698'},
#   'brewery_name': 'Pentrich Brewing Co.',
#   'brewery_location': 'Pentrich, Derbyshire England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '223 Beers 104,944 Ratings',
#   'brewery_ratings': '(3.902)'},
#  {'_id': {'$oid': '64235b8b99268f500774d699'},
#   'brewery_name': 'Chain House Brewing Co.',
#   'brewery_location': 'Preston, Lancashire England',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '88 Beers 4,643 Ratings',
#   'brewery_ratings': '(3.902)'},
#  {'_id': {'$oid': '64235b8b99268f500774d69a'},
#   'brewery_name': 'Bang The Elephant Brewing Co',
#   'brewery_location': 'Langley Mill, England England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '123 Beers 11,371 Ratings',
#   'brewery_ratings': '(3.899)'},
#  {'_id': {'$oid': '64235b8b99268f500774d69b'},
#   'brewery_name': 'Little Earth Project',
#   'brewery_location': 'Edwardstone, Suffolk England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '125 Beers 26,237 Ratings',
#   'brewery_ratings': '(3.898)'},
#  {'_id': {'$oid': '64235b8b99268f500774d69c'},
#   'brewery_name': 'Missing Link Brewing',
#   'brewery_location': 'West Hoathly, West Sussex England',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '20 Beers 6,243 Ratings',
#   'brewery_ratings': '(3.897)'},
#  {'_id': {'$oid': '64235b8b99268f500774d69d'},
#   'brewery_name': 'Wander Beyond Brewing',
#   'brewery_location': 'Manchester, Greater Manchester England',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '125 Beers 167,644 Ratings',
#   'brewery_ratings': '(3.895)'},
#  {'_id': {'$oid': '64235b8b99268f500774d69e'},
# ...
#   'brewery_name': 'Treaty City Brewery',
#   'brewery_location': 'Limerick, County Limerick Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '82 Beers 6,946 Ratings',
#   'brewery_ratings': '(3.585)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca02b'},
#   'brewery_name': 'Eight Degrees Brewing',
#   'brewery_location': 'Mitchelstown, County Cork Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '81 Beers 76,154 Ratings',
#   'brewery_ratings': '(3.58)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca02c'},
#   'brewery_name': 'Black Donkey Brewing',
#   'brewery_location': 'Ballinlough, Co. Roscommon Ireland',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '26 Beers 6,028 Ratings',
#   'brewery_ratings': '(3.576)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca02d'},
#   'brewery_name': 'Stone Barrel Brewing',
#   'brewery_location': 'Dublin, County Dublin Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '30 Beers 13,878 Ratings',
#   'brewery_ratings': '(3.574)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca02e'},
#   'brewery_name': 'The White Hag Irish Brewing Company',
#   'brewery_location': 'Ballymote, County Sligo Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '111 Beers 244,902 Ratings',
#   'brewery_ratings': '(3.573)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca02f'},
#   'brewery_name': 'BRÚ Brewery',
#   'brewery_location': 'Trim, Leinster Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '30 Beers 10,167 Ratings',
#   'brewery_ratings': '(3.571)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca030'},
#   'brewery_name': 'Ballykilcavan',
#   'brewery_location': 'Stradbally, County Laois Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '39 Beers 4,939 Ratings',
#   'brewery_ratings': '(3.571)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca031'},
#   'brewery_name': '12 Acres Brewing Company',
#   'brewery_location': 'Portarlington, County Laois Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '14 Beers 7,412 Ratings',
#   'brewery_ratings': '(3.57)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca032'},
#   'brewery_name': 'Kildare Brewing Co.',
#   'brewery_location': 'Sallins, County Kildare Ireland',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '32 Beers 1,008 Ratings',
#   'brewery_ratings': '(3.569)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca033'},
#   'brewery_name': "Dan Kelly's Cider",
#   'brewery_location': 'Drogheda, County Louth Ireland',
#   'brewery_type': 'Cidery',
#   'number_beers': '11 Beers 1,008 Ratings',
#   'brewery_ratings': '(3.567)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca034'},
#   'brewery_name': 'Rascals Brewing Co',
#   'brewery_location': 'Dublin, Leinster Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '140 Beers 57,468 Ratings',
#   'brewery_ratings': '(3.563)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca035'},
#   'brewery_name': 'Blacks Brewery',
#   'brewery_location': 'Kinsale, County Cork Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '41 Beers 44,723 Ratings',
#   'brewery_ratings': '(3.554)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca036'},
#   'brewery_name': 'HOPKINS & HOPKINS',
#   'brewery_location': 'Dublin, County Dublin Ireland',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '21 Beers 2,131 Ratings',
#   'brewery_ratings': '(3.551)'},
#  {'_id': {'$oid': '642374666ac02d0ee78ca037'},
#   'brewery_name': 'Spiddal River',
#   'brewery_location': 'Spiddal, Co. Galway Ireland',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '8 Beers 1,690 Ratings',
#   'brewery_ratings': '(3.536)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca039'},
#   'brewery_name': 'Brasseria Della Fonte',
#   'brewery_location': 'Pienza, Toscana Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '82 Beers 15,020 Ratings',
#   'brewery_ratings': '(4.057)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca03a'},
#   'brewery_name': "Ca' del Brado",
#   'brewery_location': 'Pianoro, Emilia-Romagna Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '37 Beers 36,886 Ratings',
#   'brewery_ratings': '(3.987)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca03b'},
#   'brewery_name': 'Cantina Errante',
#   'brewery_location': "Barberino Val d'Elsa, Toscana Italy",
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '45 Beers 5,227 Ratings',
#   'brewery_ratings': '(3.981)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca03c'},
#   'brewery_name': 'Alder Beer Co.',
#   'brewery_location': 'Seregno, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '55 Beers 21,937 Ratings',
#   'brewery_ratings': '(3.979)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca03d'},
#   'brewery_name': 'Siemàn',
#   'brewery_location': 'Villaga, Veneto Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '20 Beers 6,172 Ratings',
#   'brewery_ratings': '(3.921)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca03e'},
#   'brewery_name': 'Ritual Lab',
#   'brewery_location': 'Formello, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '88 Beers 41,572 Ratings',
#   'brewery_ratings': '(3.902)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca03f'},
#   'brewery_name': 'CRAK Brewery',
#   'brewery_location': 'Campodarsego, Veneto Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '258 Beers 179,082 Ratings',
#   'brewery_ratings': '(3.867)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca040'},
#   'brewery_name': 'Maestri del Sannio',
#   'brewery_location': 'Cerreto Sannita, Campania Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '53 Beers 1,957 Ratings',
#   'brewery_ratings': '(3.859)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca041'},
#   'brewery_name': 'Klanbarrique',
#   'brewery_location': 'Rovereto, Trentino-Alto Adige/Südtirol Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '40 Beers 11,958 Ratings',
#   'brewery_ratings': '(3.853)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca042'},
#   'brewery_name': 'Birrificio MalaRipe',
#   'brewery_location': 'Ripe San Ginesio, Marche Italy',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '29 Beers 1,087 Ratings',
#   'brewery_ratings': '(3.834)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca043'},
#   'brewery_name': 'Birrificio Stradaregina',
#   'brewery_location': 'Vigevano, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '99 Beers 7,233 Ratings',
#   'brewery_ratings': '(3.827)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca044'},
#   'brewery_name': 'Birrificio Montegioco',
#   'brewery_location': 'Montegioco, Piemonte Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '65 Beers 20,078 Ratings',
#   'brewery_ratings': '(3.826)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca045'},
#   'brewery_name': 'Mukkeller',
#   'brewery_location': "Porto Sant'Elpidio, Marche Italy",
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '86 Beers 10,929 Ratings',
#   'brewery_ratings': '(3.823)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca046'},
#   'brewery_name': 'Vento Forte',
#   'brewery_location': 'Bracciano, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '195 Beers 14,822 Ratings',
#   'brewery_ratings': '(3.822)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca047'},
#   'brewery_name': 'Bonavena Brewing Company',
#   'brewery_location': 'Faicchio, Campania Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '48 Beers 10,737 Ratings',
#   'brewery_ratings': '(3.821)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca048'},
#   'brewery_name': 'Hammer - Italian Craft Beer',
#   'brewery_location': 'Bergamo, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '56 Beers 34,969 Ratings',
#   'brewery_ratings': '(3.82)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca049'},
#   'brewery_name': 'LIQUIDA Birrificio Indipendente',
#   'brewery_location': 'Ostellato, Emilia-Romagna Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '51 Beers 8,744 Ratings',
#   'brewery_ratings': '(3.8)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca04a'},
#   'brewery_name': 'Birra MC - 77',
#   'brewery_location': 'Caccamo, Marche Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '86 Beers 16,552 Ratings',
#   'brewery_ratings': '(3.796)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca04b'},
#   'brewery_name': 'AltaVia Agribirrificio',
#   'brewery_location': 'Sassello, Liguria Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '50 Beers 3,681 Ratings',
#   'brewery_ratings': '(3.784)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca04c'},
#   'brewery_name': 'LoverBeer',
#   'brewery_location': 'Marentino, Piemonte Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '49 Beers 66,824 Ratings',
#   'brewery_ratings': '(3.783)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca04d'},
#   'brewery_name': 'Extraomnes',
#   'brewery_location': 'Marnate, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '84 Beers 37,439 Ratings',
#   'brewery_ratings': '(3.77)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca04e'},
#   'brewery_name': 'Shire Brewing',
#   'brewery_location': 'Porciano, Lazio Italy',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '13 Beers 2,416 Ratings',
#   'brewery_ratings': '(3.759)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca04f'},
#   'brewery_name': 'Birra Elvo',
#   'brewery_location': 'Graglia, Piemonte Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '38 Beers 8,867 Ratings',
#   'brewery_ratings': '(3.754)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca050'},
#   'brewery_name': 'Barley',
#   'brewery_location': 'Maracalagonis, Sardegna Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '44 Beers 8,226 Ratings',
#   'brewery_ratings': '(3.751)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca051'},
#   'brewery_name': "Birrificio Foglie d'Erba",
#   'brewery_location': 'Forni di Sopra, Friuli Venezia Giulia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '102 Beers 11,020 Ratings',
#   'brewery_ratings': '(3.745)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca052'},
#   'brewery_name': 'Hilltop Brewery',
#   'brewery_location': 'Bassano Romano, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '75 Beers 14,416 Ratings',
#   'brewery_ratings': '(3.745)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca053'},
#   'brewery_name': 'Nama Brewing',
#   'brewery_location': 'Treviglio, Lombardy Italy',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '19 Beers 1,216 Ratings',
#   'brewery_ratings': '(3.745)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca054'},
#   'brewery_name': 'Nix',
#   'brewery_location': 'Pavia, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '8 Beers 3,190 Ratings',
#   'brewery_ratings': '(3.741)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca055'},
#   'brewery_name': 'Birra del Carrobiolo',
#   'brewery_location': 'Monza, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '111 Beers 10,099 Ratings',
#   'brewery_ratings': '(3.74)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca056'},
#   'brewery_name': 'Birrificio Porta Bruciata',
#   'brewery_location': 'Rodengo-Saiano, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '34 Beers 9,259 Ratings',
#   'brewery_ratings': '(3.735)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca057'},
#   'brewery_name': 'Birrificio Bondai',
#   'brewery_location': 'Sutrio, Friuli Venezia Giulia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '16 Beers 2,053 Ratings',
#   'brewery_ratings': '(3.729)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca058'},
#   'brewery_name': 'OpperBacco',
#   'brewery_location': 'Notaresco, Abruzzo Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '149 Beers 25,859 Ratings',
#   'brewery_ratings': '(3.726)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca059'},
#   'brewery_name': 'Birrificio Menaresta',
#   'brewery_location': 'Carate Brianza, Lombardia Italy',
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '109 Beers 19,456 Ratings',
#   'brewery_ratings': '(3.725)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca05a'},
#   'brewery_name': "Birrificio BioNoc'",
#   'brewery_location': 'Mezzano, Trentino-Alto Adige/Südtirol Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '59 Beers 6,632 Ratings',
#   'brewery_ratings': '(3.723)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca05b'},
#   'brewery_name': 'Eastside Brewing',
#   'brewery_location': 'Latina, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '79 Beers 31,095 Ratings',
#   'brewery_ratings': '(3.723)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca05c'},
#   'brewery_name': "Rebel's Brewery",
#   'brewery_location': 'Roma, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '65 Beers 20,348 Ratings',
#   'brewery_ratings': '(3.72)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca05d'},
#   'brewery_name': 'Buskers Beer',
#   'brewery_location': 'Roma, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '32 Beers 2,503 Ratings',
#   'brewery_ratings': '(3.718)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca05e'},
#   'brewery_name': 'Hop Skin',
#   'brewery_location': 'Curno, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '104 Beers 9,869 Ratings',
#   'brewery_ratings': '(3.718)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca05f'},
#   'brewery_name': 'Kashmir',
#   'brewery_location': 'Filignano, Molise Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '59 Beers 1,467 Ratings',
#   'brewery_ratings': '(3.717)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca060'},
#   'brewery_name': 'Jungle Juice Brewing',
#   'brewery_location': 'Roma, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '87 Beers 14,898 Ratings',
#   'brewery_ratings': '(3.714)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca061'},
#   'brewery_name': 'Black Barrels',
#   'brewery_location': 'Turin, Piemonte Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '48 Beers 3,230 Ratings',
#   'brewery_ratings': '(3.713)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca062'},
#   'brewery_name': 'Ballarak',
#   'brewery_location': 'Palermo, Sicilia Italy',
#   'brewery_type': 'Brew Pub',
#   'number_beers': '25 Beers 1,563 Ratings',
#   'brewery_ratings': '(3.702)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca063'},
#   'brewery_name': 'Birra Due Tocchi',
#   'brewery_location': 'Parabiago, Lombardia Italy',
#   'brewery_type': 'Contract Brewery',
#   'number_beers': '13 Beers 1,176 Ratings',
#   'brewery_ratings': '(3.7)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca064'},
#   'brewery_name': 'Birrificio Altotevere',
#   'brewery_location': 'San Giustino, Umbria Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '32 Beers 6,574 Ratings',
#   'brewery_ratings': '(3.699)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca065'},
#   'brewery_name': 'Birrificio Lambrate',
#   'brewery_location': 'Milan, Lombardia Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '133 Beers 94,218 Ratings',
#   'brewery_ratings': '(3.69)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca066'},
#   'brewery_name': 'South Soul',
#   'brewery_location': 'Francolise, Campania Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '15 Beers 1,603 Ratings',
#   'brewery_ratings': '(3.689)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca067'},
#   'brewery_name': 'Passion Italian Craft Brewery',
#   'brewery_location': 'Trento, Trentino-Alto Adige/Südtirol Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '26 Beers 3,581 Ratings',
#   'brewery_ratings': '(3.689)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca068'},
#   'brewery_name': 'Malcantone',
#   'brewery_location': "Ozzano dell'Emilia, Emilia-Romagna Italy",
#   'brewery_type': 'Nano Brewery',
#   'number_beers': '25 Beers 1,448 Ratings',
#   'brewery_ratings': '(3.688)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca069'},
#   'brewery_name': 'Chianti Brew Fighters',
#   'brewery_location': 'Radda in Chianti, Toscana Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '39 Beers 3,689 Ratings',
#   'brewery_ratings': '(3.687)'},
#  {'_id': {'$oid': '642374dd6ac02d0ee78ca06a'},
#   'brewery_name': 'Terre Di Faul',
#   'brewery_location': 'Viterbo, Lazio Italy',
#   'brewery_type': 'Micro Brewery',
#   'number_beers': '31 Beers 1,699 Ratings',
#   'brewery_ratings': '(3.683)'}]

# %%
data[2]["brewery_name"]
# Out:
# 'Brewlihan'

# %%
import json

with open('brewery_untappd_export_MD.json', 'r', encoding="utf8") as myfile:
    data_untappd = myfile.read()

data= json.loads(data_untappd)

import re

string = data[3]["brewery_location"]
pattern = "(?!([A-Za-z]+),\s([A-Za-z]+)\s)[A-Za-z]+"

match = re.search(pattern, string)

match
# Out:
# <re.Match object; span=(9, 11), match='FL'>

# %%
string
# Out:
# 'Orlando, FL United States'

# %%
re.find(pattern, string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16508\4287180302.py in <module>
# ----> 1 re.find(pattern, string)
#
# AttributeError: module 're' has no attribute 'find'

# %%
import re

string = "100 pesos"
pattern = "\d+(?!\d| dollars)"

match = re.search(pattern, string)
match
# Out:
# <re.Match object; span=(0, 3), match='100'>
